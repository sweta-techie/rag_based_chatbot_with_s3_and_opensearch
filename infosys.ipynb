# %%
d_dict = {
   "a": 1,
   "b": {
       "c": 2,
       "d": {
           "e": 3
       }
   },
   "f": {
       "g": 4
   }
}
def is_dict(d_dict):
    for key,value in d_dict.items():
        if(isinstance(value,dict)):
            is_dict(value)
        else:
            print(key,value) 

def main():
    # for key,value in d_dict.items():
    #     is_dict(value)
    is_dict(d_dict)
main()    
    



         


    
        
    

    # print(key,value)
# Out:
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# a 1
# ...
